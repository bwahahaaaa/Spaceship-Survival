# %% [markdown]
# # **Spaceship Survival Game**
#
# *Problem Statement*: You are developing a mobile game where players control a spaceship navigating through an asteroid field. The objective is to avoid collisions with the asteroids for as long as possible. The game environment is represented as a 2D grid, where the spaceship can move up, down, left, or right.
#
# Spaceship should pass through the obstacles and try to survive for a maximum time possible. The spaceship can move up(↑), down(↓), right(→), or left(←).
#
# *Objective*: Design a deep neural network that takes the current state of the game environment (i.e., the positions of the spaceship and asteroids on the grid) as input and outputs the optimal action (i.e., move up, down, left, or right) to maximize the spaceship's survival time.
#
# *Additional Information*:
#
# The game environment is dynamic, with asteroids moving randomly across the grid.
# The spaceship's movement speed and agility are constant.
# The reward system is based on the survival time, with higher rewards for longer survival durations.
# The neural network should use function approximation to learn the optimal policy for navigating the spaceship through the asteroid field.

# %% [markdown]
# **Elaborate on, how the described problem could be solved using deep neural network and explain the action plan to create a gaming environment**
#
# Environment Setup: Design a 2D grid environment where a spaceship navigates through moving asteroids.
#
# State Representation: Represent the game state with spaceship and asteroid positions.
#
# Action Space: Define discrete actions for the spaceship: up, down, left, and right.
#
# Reward System: Implement a reward function based on survival time without collisions.
#
# Deep Q-Network (DQN):
#
# Neural Network: Create a neural network to map states to actions.
# Experience Replay: Store experiences to stabilize training.
# Target Network: Use a separate network for stability.
# Q-Learning Update: Update Q-values based on observed rewards.
# Epsilon-Greedy Policy: Balance exploration and exploitation.
# Training: Interact with the environment, updating the network to maximize rewards.
#
# Testing: Evaluate the trained model to measure performance metrics.
#
# Fine-tuning: Refine the model and environment iteratively for better performance.
#
# Following this plan should lead to an effective spaceship navigation system through the asteroid field.

# %% [markdown]
# **Implementation**

# %%
#Defining the game environment and creating a custom OpenAI Gym environment called SpaceShipEnv.

import gym
from gym import spaces
import numpy as np

class SpaceShipEnv(gym.Env):
    def __init__(self, grid_size=(10, 10), num_asteroids=10):
        super(SpaceShipEnv, self).__init__()

        # Define grid size
        self.grid_size = grid_size
        self.num_rows, self.num_cols = self.grid_size

        # Define action and observation spaces
        self.action_space = spaces.Discrete(4)  # 4 possible actions: up, down, left, right
        self.observation_space = spaces.Box(low=0, high=2, shape=(self.num_rows, self.num_cols), dtype=np.uint8)

        # Define other parameters
        self.num_asteroids = num_asteroids
        self.asteroids = []

        self.reset()

    def reset(self):
        # Initialize spaceship position
        self.spaceship_pos = [np.random.randint(0, self.num_rows), np.random.randint(0, self.num_cols)]

        # Initialize asteroids
        self.asteroids = []
        for _ in range(self.num_asteroids):
            asteroid_pos = [np.random.randint(0, self.num_rows), np.random.randint(0, self.num_cols)]
            while asteroid_pos == self.spaceship_pos:
                asteroid_pos = [np.random.randint(0, self.num_rows), np.random.randint(0, self.num_cols)]
            self.asteroids.append(asteroid_pos)

        # Reset step count
        self.steps = 0

        # Return initial observation
        return self._get_observation()

    def step(self, action):
        # Execute action
        if action == 0:  # Up
            self.spaceship_pos[0] = max(0, self.spaceship_pos[0] - 1)
        elif action == 1:  # Down
            self.spaceship_pos[0] = min(self.num_rows - 1, self.spaceship_pos[0] + 1)
        elif action == 2:  # Left
            self.spaceship_pos[1] = max(0, self.spaceship_pos[1] - 1)
        elif action == 3:  # Right
            self.spaceship_pos[1] = min(self.num_cols - 1, self.spaceship_pos[1] + 1)

        # Check for collision with asteroids
        reward = -1
        done = False
        for asteroid_pos in self.asteroids:
            if asteroid_pos == self.spaceship_pos:
                reward = -10
                done = True
                break

        # Update step count
        self.steps += 1

        # Return next observation, reward, done, info
        return self._get_observation(), reward, done, {}

    def _get_observation(self):
        # Create grid with spaceship and asteroids
        observation = np.zeros((self.num_rows, self.num_cols), dtype=np.uint8)
        observation[self.spaceship_pos[0], self.spaceship_pos[1]] = 1
        for asteroid_pos in self.asteroids:
            observation[asteroid_pos[0], asteroid_pos[1]] = 2

        return observation

# %% [markdown]
# In this environment:
#
# The state space is represented by a 2D grid where each cell can be empty, contain the spaceship (value 1), or an asteroid (value 2).
# The action space consists of four discrete actions: 0 for moving up, 1 for moving down, 2 for moving left, and 3 for moving right.
# The reward is -1 for each step taken, and -10 if the spaceship collides with an asteroid.
# The episode terminates when the spaceship collides with an asteroid.
# This environment can be used for training and evaluating the spaceship agent to avoid collisions with asteroids and maximize its survival time.

# %%
#Creating a class called ReplayBuffer that stores experiences (state, action, reward, next state, terminal flag) and provides methods to add experiences and sample batches of experiences for training

from collections import deque
import random

class ReplayBuffer:
    def __init__(self, max_size):
        self.buffer = deque(maxlen=max_size)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = map(np.array, zip(*batch))
        return states, actions, rewards, next_states, dones

# %%
#Designing the neural network architecture for the DQN using Convolutional Neural Networks.

import tensorflow as tf

class DQN(tf.keras.Model):
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        self.conv1 = tf.keras.layers.Conv2D(32, kernel_size=8, strides=4, activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, kernel_size=4, strides=2, activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu')
        self.flatten = tf.keras.layers.Flatten()
        self.fc1 = tf.keras.layers.Dense(512, activation='relu')
        self.fc2 = tf.keras.layers.Dense(num_actions)

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        x = self.fc1(x)
        q_values = self.fc2(x)
        return q_values

# %% [markdown]
# In this architecture:
#
# -We use three convolutional layers (Conv2D) with ReLU activation functions to extract features from the input game state.
#
# -The output of the last convolutional layer is flattened (Flatten), and then passed through two fully connected (dense) layers (Dense) with ReLU activation functions.
#
# -The final fully connected layer outputs the Q-values for each possible action.

# %%
#Epsilon-Greedy Exploration

import numpy as np

class DQNAgent:
    def __init__(self, state_size, action_size):
        # Other initialization code...
        self.epsilon = 1.0  # Initial exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            # Explore: Select a random action
            return np.random.randint(self.action_size)
        else:
            # Exploit: Select the action with the highest Q-value
            q_values = self.model.predict(state)
            return np.argmax(q_values[0])

    def replay(self, batch_size):
        # Replay buffer and training code...
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# In this implementation:
#
# -During each action selection, with probability epsilon, the agent explores by selecting a random action.
#
# -With probability 1 - epsilon, the agent exploits by selecting the action with the highest Q-value according to the current policy.
#
# -The value of epsilon is decayed over time to gradually shift towards more exploitation and less exploration as training progresses.

# %%
#Implementing training loop for DQN Agent

class DQNAgent:
    def __init__(self, state_size, action_size):
        # Initialization code...
        self.model = DQN(action_size)
        self.target_model = DQN(action_size)
        self.target_model.set_weights(self.model.get_weights())

    def train(self, env, num_episodes, batch_size):
        for episode in range(num_episodes):
            state = env.reset()
            state = np.reshape(state, [1, state_size[0], state_size[1], state_size[2]])
            total_reward = 0
            while True:
                action = self.act(state)
                next_state, reward, done, _ = env.step(action)
                next_state = np.reshape(next_state, [1, state_size[0], state_size[1], state_size[2]])
                total_reward += reward

                self.remember(state, action, reward, next_state, done)

                state = next_state

                if done:
                    break

                self.replay(batch_size)
                self.update_target_model()

            print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}")

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

# %% [markdown]
# In this implementation:
#
# -The train method trains the DQN agent in the given environment for a specified number of episodes.
#
# -Within each episode, it follows the training loop described above: selects actions, executes them in the environment, stores experiences in the replay buffer, samples a batch of experiences, computes target Q-values, updates the Q-network, and periodically updates the target network.
#
# -The update_target_model method updates the weights of the target network to match the current weights of the Q-network. This update typically occurs periodically to stabilize training.

# %%
#Training and Evaluation

import numpy as np

class DQN:
    def __init__(self, num_actions):
        pass

    def predict(self, state):
        pass

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.model = DQN(action_size)
        self.target_model = DQN(action_size)
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.randint(self.action_size)
        else:
            q_values = self.model.predict(state)
            return np.argmax(q_values[0])

    def remember(self, state, action, reward, next_state, done):
        pass

    def replay(self, batch_size):
        pass

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def train(self, env, num_episodes, batch_size):
        for episode in range(num_episodes):
            state = env.reset()
            state = np.reshape(state, [1, *self.state_size])  # Adjusted for 2D state
            total_reward = 0
            while True:
                action = self.act(state)
                next_state, reward, done, _ = env.step(action)
                next_state = np.reshape(next_state, [1, *self.state_size])  # Adjusted for 2D state
                total_reward += reward

                self.remember(state, action, reward, next_state, done)

                state = next_state

                if done:
                    break

            print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}")

# Initialize environment and agent
env = SpaceShipEnv()
state_size = env.observation_space.shape
action_size = env.action_space.n
agent = DQNAgent(state_size, action_size)

# Train agent
num_episodes = 1000
batch_size = 32
agent.train(env, num_episodes, batch_size)

# Test agent
test_episodes = 10
total_rewards = []
for _ in range(test_episodes):
    state = env.reset()
    state = np.reshape(state, [1, *state_size])
    total_reward = 0
    while True:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        total_reward += reward
        state = np.reshape(next_state, [1, *state_size])
        if done:
            break
    total_rewards.append(total_reward)

average_reward = sum(total_rewards) / len(total_rewards)
print(f"Average reward over {test_episodes} test episodes: {average_reward}")
# Out:
# Episode 1/1000, Total Reward: -18
# Episode 2/1000, Total Reward: -20
# Episode 3/1000, Total Reward: -10
# Episode 4/1000, Total Reward: -13
# Episode 5/1000, Total Reward: -10
# Episode 6/1000, Total Reward: -57
# Episode 7/1000, Total Reward: -13
# Episode 8/1000, Total Reward: -19
# Episode 9/1000, Total Reward: -21
# Episode 10/1000, Total Reward: -15
# Episode 11/1000, Total Reward: -15
# Episode 12/1000, Total Reward: -54
# Episode 13/1000, Total Reward: -61
# Episode 14/1000, Total Reward: -43
# Episode 15/1000, Total Reward: -14
# Episode 16/1000, Total Reward: -21
# Episode 17/1000, Total Reward: -28
# Episode 18/1000, Total Reward: -76
# Episode 19/1000, Total Reward: -32
# Episode 20/1000, Total Reward: -74
# Episode 21/1000, Total Reward: -11
# Episode 22/1000, Total Reward: -12
# Episode 23/1000, Total Reward: -12
# Episode 24/1000, Total Reward: -39
# Episode 25/1000, Total Reward: -25
# Episode 26/1000, Total Reward: -64
# Episode 27/1000, Total Reward: -20
# Episode 28/1000, Total Reward: -26
# Episode 29/1000, Total Reward: -20
# Episode 30/1000, Total Reward: -10
# Episode 31/1000, Total Reward: -13
# Episode 32/1000, Total Reward: -15
# Episode 33/1000, Total Reward: -31
# Episode 34/1000, Total Reward: -11
# Episode 35/1000, Total Reward: -24
# Episode 36/1000, Total Reward: -21
# Episode 37/1000, Total Reward: -10
# Episode 38/1000, Total Reward: -16
# Episode 39/1000, Total Reward: -15
# Episode 40/1000, Total Reward: -114
# Episode 41/1000, Total Reward: -108
# Episode 42/1000, Total Reward: -67
# Episode 43/1000, Total Reward: -22
# Episode 44/1000, Total Reward: -19
# Episode 45/1000, Total Reward: -17
# Episode 46/1000, Total Reward: -15
# Episode 47/1000, Total Reward: -57
# Episode 48/1000, Total Reward: -58
# Episode 49/1000, Total Reward: -21
# Episode 50/1000, Total Reward: -45
# Episode 51/1000, Total Reward: -81
# Episode 52/1000, Total Reward: -18
# Episode 53/1000, Total Reward: -44
# Episode 54/1000, Total Reward: -171
# Episode 55/1000, Total Reward: -11
# Episode 56/1000, Total Reward: -37
# Episode 57/1000, Total Reward: -10
# Episode 58/1000, Total Reward: -48
# Episode 59/1000, Total Reward: -36
# Episode 60/1000, Total Reward: -13
# Episode 61/1000, Total Reward: -100
# Episode 62/1000, Total Reward: -74
# Episode 63/1000, Total Reward: -19
# Episode 64/1000, Total Reward: -11
# Episode 65/1000, Total Reward: -13
# Episode 66/1000, Total Reward: -10
# Episode 67/1000, Total Reward: -49
# Episode 68/1000, Total Reward: -16
# Episode 69/1000, Total Reward: -30
# Episode 70/1000, Total Reward: -10
# Episode 71/1000, Total Reward: -66
# Episode 72/1000, Total Reward: -16
# Episode 73/1000, Total Reward: -22
# Episode 74/1000, Total Reward: -14
# Episode 75/1000, Total Reward: -31
# Episode 76/1000, Total Reward: -55
# Episode 77/1000, Total Reward: -11
# Episode 78/1000, Total Reward: -11
# Episode 79/1000, Total Reward: -32
# Episode 80/1000, Total Reward: -49
# Episode 81/1000, Total Reward: -30
# Episode 82/1000, Total Reward: -92
# Episode 83/1000, Total Reward: -38
# Episode 84/1000, Total Reward: -12
# Episode 85/1000, Total Reward: -17
# Episode 86/1000, Total Reward: -18
# Episode 87/1000, Total Reward: -11
# Episode 88/1000, Total Reward: -18
# Episode 89/1000, Total Reward: -28
# Episode 90/1000, Total Reward: -47
# Episode 91/1000, Total Reward: -39
# Episode 92/1000, Total Reward: -38
# Episode 93/1000, Total Reward: -94
# Episode 94/1000, Total Reward: -119
# Episode 95/1000, Total Reward: -10
# Episode 96/1000, Total Reward: -17
# Episode 97/1000, Total Reward: -11
# Episode 98/1000, Total Reward: -11
# Episode 99/1000, Total Reward: -53
# Episode 100/1000, Total Reward: -12
# Episode 101/1000, Total Reward: -12
# Episode 102/1000, Total Reward: -15
# Episode 103/1000, Total Reward: -17
# Episode 104/1000, Total Reward: -26
# Episode 105/1000, Total Reward: -11
# Episode 106/1000, Total Reward: -10
# Episode 107/1000, Total Reward: -26
# Episode 108/1000, Total Reward: -15
# Episode 109/1000, Total Reward: -32
# Episode 110/1000, Total Reward: -17
# Episode 111/1000, Total Reward: -12
# Episode 112/1000, Total Reward: -12
# Episode 113/1000, Total Reward: -14
# Episode 114/1000, Total Reward: -20
# Episode 115/1000, Total Reward: -16
# Episode 116/1000, Total Reward: -19
# Episode 117/1000, Total Reward: -62
# Episode 118/1000, Total Reward: -19
# Episode 119/1000, Total Reward: -31
# Episode 120/1000, Total Reward: -21
# Episode 121/1000, Total Reward: -14
# Episode 122/1000, Total Reward: -10
# Episode 123/1000, Total Reward: -51
# Episode 124/1000, Total Reward: -17
# Episode 125/1000, Total Reward: -25
# Episode 126/1000, Total Reward: -18
# Episode 127/1000, Total Reward: -14
# Episode 128/1000, Total Reward: -52
# Episode 129/1000, Total Reward: -14
# Episode 130/1000, Total Reward: -37
# Episode 131/1000, Total Reward: -87
# Episode 132/1000, Total Reward: -31
# Episode 133/1000, Total Reward: -18
# Episode 134/1000, Total Reward: -25
# Episode 135/1000, Total Reward: -84
# Episode 136/1000, Total Reward: -43
# Episode 137/1000, Total Reward: -14
# Episode 138/1000, Total Reward: -45
# Episode 139/1000, Total Reward: -13
# Episode 140/1000, Total Reward: -24
# Episode 141/1000, Total Reward: -16
# Episode 142/1000, Total Reward: -47
# Episode 143/1000, Total Reward: -51
# Episode 144/1000, Total Reward: -48
# Episode 145/1000, Total Reward: -75
# Episode 146/1000, Total Reward: -35
# Episode 147/1000, Total Reward: -22
# Episode 148/1000, Total Reward: -56
# Episode 149/1000, Total Reward: -12
# Episode 150/1000, Total Reward: -29
# Episode 151/1000, Total Reward: -17
# Episode 152/1000, Total Reward: -13
# Episode 153/1000, Total Reward: -21
# Episode 154/1000, Total Reward: -50
# Episode 155/1000, Total Reward: -17
# Episode 156/1000, Total Reward: -17
# Episode 157/1000, Total Reward: -19
# Episode 158/1000, Total Reward: -64
# Episode 159/1000, Total Reward: -56
# Episode 160/1000, Total Reward: -126
# Episode 161/1000, Total Reward: -17
# Episode 162/1000, Total Reward: -18
# Episode 163/1000, Total Reward: -47
# Episode 164/1000, Total Reward: -78
# Episode 165/1000, Total Reward: -16
# Episode 166/1000, Total Reward: -20
# Episode 167/1000, Total Reward: -24
# Episode 168/1000, Total Reward: -21
# Episode 169/1000, Total Reward: -10
# Episode 170/1000, Total Reward: -54
# Episode 171/1000, Total Reward: -20
# Episode 172/1000, Total Reward: -50
# Episode 173/1000, Total Reward: -88
# Episode 174/1000, Total Reward: -13
# Episode 175/1000, Total Reward: -29
# Episode 176/1000, Total Reward: -43
# Episode 177/1000, Total Reward: -24
# Episode 178/1000, Total Reward: -10
# Episode 179/1000, Total Reward: -90
# Episode 180/1000, Total Reward: -30
# Episode 181/1000, Total Reward: -15
# Episode 182/1000, Total Reward: -24
# Episode 183/1000, Total Reward: -18
# Episode 184/1000, Total Reward: -38
# Episode 185/1000, Total Reward: -29
# Episode 186/1000, Total Reward: -10
# Episode 187/1000, Total Reward: -53
# Episode 188/1000, Total Reward: -26
# Episode 189/1000, Total Reward: -11
# Episode 190/1000, Total Reward: -34
# Episode 191/1000, Total Reward: -10
# Episode 192/1000, Total Reward: -25
# Episode 193/1000, Total Reward: -10
# Episode 194/1000, Total Reward: -15
# Episode 195/1000, Total Reward: -10
# Episode 196/1000, Total Reward: -10
# Episode 197/1000, Total Reward: -19
# Episode 198/1000, Total Reward: -22
# Episode 199/1000, Total Reward: -19
# Episode 200/1000, Total Reward: -56
# Episode 201/1000, Total Reward: -25
# Episode 202/1000, Total Reward: -46
# Episode 203/1000, Total Reward: -33
# Episode 204/1000, Total Reward: -18
# Episode 205/1000, Total Reward: -69
# Episode 206/1000, Total Reward: -13
# Episode 207/1000, Total Reward: -12
# Episode 208/1000, Total Reward: -12
# Episode 209/1000, Total Reward: -36
# Episode 210/1000, Total Reward: -22
# Episode 211/1000, Total Reward: -51
# Episode 212/1000, Total Reward: -19
# Episode 213/1000, Total Reward: -14
# Episode 214/1000, Total Reward: -20
# Episode 215/1000, Total Reward: -23
# Episode 216/1000, Total Reward: -11
# Episode 217/1000, Total Reward: -34
# Episode 218/1000, Total Reward: -19
# Episode 219/1000, Total Reward: -10
# Episode 220/1000, Total Reward: -29
# Episode 221/1000, Total Reward: -24
# Episode 222/1000, Total Reward: -45
# Episode 223/1000, Total Reward: -20
# Episode 224/1000, Total Reward: -16
# Episode 225/1000, Total Reward: -54
# Episode 226/1000, Total Reward: -29
# Episode 227/1000, Total Reward: -27
# Episode 228/1000, Total Reward: -72
# Episode 229/1000, Total Reward: -25
# Episode 230/1000, Total Reward: -18
# Episode 231/1000, Total Reward: -35
# Episode 232/1000, Total Reward: -10
# Episode 233/1000, Total Reward: -23
# Episode 234/1000, Total Reward: -33
# Episode 235/1000, Total Reward: -28
# Episode 236/1000, Total Reward: -68
# Episode 237/1000, Total Reward: -31
# Episode 238/1000, Total Reward: -10
# Episode 239/1000, Total Reward: -12
# Episode 240/1000, Total Reward: -14
# Episode 241/1000, Total Reward: -10
# Episode 242/1000, Total Reward: -54
# Episode 243/1000, Total Reward: -33
# Episode 244/1000, Total Reward: -11
# Episode 245/1000, Total Reward: -33
# Episode 246/1000, Total Reward: -51
# Episode 247/1000, Total Reward: -19
# Episode 248/1000, Total Reward: -17
# Episode 249/1000, Total Reward: -58
# Episode 250/1000, Total Reward: -45
# Episode 251/1000, Total Reward: -69
# Episode 252/1000, Total Reward: -18
# Episode 253/1000, Total Reward: -17
# Episode 254/1000, Total Reward: -11
# Episode 255/1000, Total Reward: -112
# Episode 256/1000, Total Reward: -48
# Episode 257/1000, Total Reward: -48
# Episode 258/1000, Total Reward: -105
# Episode 259/1000, Total Reward: -12
# Episode 260/1000, Total Reward: -22
# Episode 261/1000, Total Reward: -25
# Episode 262/1000, Total Reward: -19
# Episode 263/1000, Total Reward: -53
# Episode 264/1000, Total Reward: -13
# Episode 265/1000, Total Reward: -46
# Episode 266/1000, Total Reward: -125
# Episode 267/1000, Total Reward: -11
# Episode 268/1000, Total Reward: -21
# Episode 269/1000, Total Reward: -30
# Episode 270/1000, Total Reward: -31
# Episode 271/1000, Total Reward: -14
# Episode 272/1000, Total Reward: -10
# Episode 273/1000, Total Reward: -23
# Episode 274/1000, Total Reward: -39
# Episode 275/1000, Total Reward: -11
# Episode 276/1000, Total Reward: -25
# Episode 277/1000, Total Reward: -30
# Episode 278/1000, Total Reward: -64
# Episode 279/1000, Total Reward: -10
# Episode 280/1000, Total Reward: -29
# Episode 281/1000, Total Reward: -12
# Episode 282/1000, Total Reward: -62
# Episode 283/1000, Total Reward: -12
# Episode 284/1000, Total Reward: -32
# Episode 285/1000, Total Reward: -11
# Episode 286/1000, Total Reward: -13
# Episode 287/1000, Total Reward: -21
# Episode 288/1000, Total Reward: -31
# Episode 289/1000, Total Reward: -67
# Episode 290/1000, Total Reward: -14
# Episode 291/1000, Total Reward: -28
# Episode 292/1000, Total Reward: -10
# Episode 293/1000, Total Reward: -39
# Episode 294/1000, Total Reward: -31
# Episode 295/1000, Total Reward: -19
# Episode 296/1000, Total Reward: -11
# Episode 297/1000, Total Reward: -31
# Episode 298/1000, Total Reward: -28
# Episode 299/1000, Total Reward: -67
# Episode 300/1000, Total Reward: -23
# Episode 301/1000, Total Reward: -129
# Episode 302/1000, Total Reward: -14
# Episode 303/1000, Total Reward: -24
# Episode 304/1000, Total Reward: -37
# Episode 305/1000, Total Reward: -13
# Episode 306/1000, Total Reward: -23
# Episode 307/1000, Total Reward: -39
# Episode 308/1000, Total Reward: -27
# Episode 309/1000, Total Reward: -17
# Episode 310/1000, Total Reward: -31
# Episode 311/1000, Total Reward: -112
# Episode 312/1000, Total Reward: -36
# Episode 313/1000, Total Reward: -82
# Episode 314/1000, Total Reward: -27
# Episode 315/1000, Total Reward: -78
# Episode 316/1000, Total Reward: -11
# Episode 317/1000, Total Reward: -55
# Episode 318/1000, Total Reward: -108
# Episode 319/1000, Total Reward: -30
# Episode 320/1000, Total Reward: -27
# Episode 321/1000, Total Reward: -10
# Episode 322/1000, Total Reward: -91
# Episode 323/1000, Total Reward: -37
# Episode 324/1000, Total Reward: -16
# Episode 325/1000, Total Reward: -10
# Episode 326/1000, Total Reward: -39
# Episode 327/1000, Total Reward: -155
# Episode 328/1000, Total Reward: -15
# Episode 329/1000, Total Reward: -13
# Episode 330/1000, Total Reward: -17
# Episode 331/1000, Total Reward: -24
# Episode 332/1000, Total Reward: -74
# Episode 333/1000, Total Reward: -27
# Episode 334/1000, Total Reward: -13
# Episode 335/1000, Total Reward: -55
# Episode 336/1000, Total Reward: -12
# Episode 337/1000, Total Reward: -92
# Episode 338/1000, Total Reward: -19
# Episode 339/1000, Total Reward: -24
# Episode 340/1000, Total Reward: -21
# Episode 341/1000, Total Reward: -43
# Episode 342/1000, Total Reward: -15
# Episode 343/1000, Total Reward: -17
# Episode 344/1000, Total Reward: -12
# Episode 345/1000, Total Reward: -14
# Episode 346/1000, Total Reward: -12
# Episode 347/1000, Total Reward: -94
# Episode 348/1000, Total Reward: -17
# Episode 349/1000, Total Reward: -38
# Episode 350/1000, Total Reward: -85
# Episode 351/1000, Total Reward: -16
# Episode 352/1000, Total Reward: -21
# Episode 353/1000, Total Reward: -23
# Episode 354/1000, Total Reward: -10
# Episode 355/1000, Total Reward: -37
# Episode 356/1000, Total Reward: -39
# Episode 357/1000, Total Reward: -10
# Episode 358/1000, Total Reward: -10
# Episode 359/1000, Total Reward: -28
# Episode 360/1000, Total Reward: -57
# Episode 361/1000, Total Reward: -13
# Episode 362/1000, Total Reward: -21
# Episode 363/1000, Total Reward: -13
# Episode 364/1000, Total Reward: -20
# Episode 365/1000, Total Reward: -10
# Episode 366/1000, Total Reward: -12
# Episode 367/1000, Total Reward: -21
# Episode 368/1000, Total Reward: -13
# Episode 369/1000, Total Reward: -11
# Episode 370/1000, Total Reward: -13
# Episode 371/1000, Total Reward: -28
# Episode 372/1000, Total Reward: -14
# Episode 373/1000, Total Reward: -11
# Episode 374/1000, Total Reward: -25
# Episode 375/1000, Total Reward: -30
# Episode 376/1000, Total Reward: -14
# Episode 377/1000, Total Reward: -30
# Episode 378/1000, Total Reward: -10
# Episode 379/1000, Total Reward: -38
# Episode 380/1000, Total Reward: -43
# Episode 381/1000, Total Reward: -17
# Episode 382/1000, Total Reward: -27
# Episode 383/1000, Total Reward: -16
# Episode 384/1000, Total Reward: -12
# Episode 385/1000, Total Reward: -18
# Episode 386/1000, Total Reward: -19
# Episode 387/1000, Total Reward: -49
# Episode 388/1000, Total Reward: -23
# Episode 389/1000, Total Reward: -26
# Episode 390/1000, Total Reward: -12
# Episode 391/1000, Total Reward: -24
# Episode 392/1000, Total Reward: -47
# Episode 393/1000, Total Reward: -83
# Episode 394/1000, Total Reward: -32
# Episode 395/1000, Total Reward: -15
# Episode 396/1000, Total Reward: -63
# Episode 397/1000, Total Reward: -65
# Episode 398/1000, Total Reward: -68
# Episode 399/1000, Total Reward: -18
# Episode 400/1000, Total Reward: -12
# Episode 401/1000, Total Reward: -11
# Episode 402/1000, Total Reward: -38
# Episode 403/1000, Total Reward: -31
# Episode 404/1000, Total Reward: -12
# Episode 405/1000, Total Reward: -22
# Episode 406/1000, Total Reward: -16
# Episode 407/1000, Total Reward: -44
# Episode 408/1000, Total Reward: -35
# Episode 409/1000, Total Reward: -12
# Episode 410/1000, Total Reward: -22
# Episode 411/1000, Total Reward: -64
# Episode 412/1000, Total Reward: -13
# Episode 413/1000, Total Reward: -24
# Episode 414/1000, Total Reward: -92
# Episode 415/1000, Total Reward: -118
# Episode 416/1000, Total Reward: -27
# Episode 417/1000, Total Reward: -15
# Episode 418/1000, Total Reward: -70
# Episode 419/1000, Total Reward: -29
# Episode 420/1000, Total Reward: -23
# Episode 421/1000, Total Reward: -38
# Episode 422/1000, Total Reward: -18
# Episode 423/1000, Total Reward: -13
# Episode 424/1000, Total Reward: -12
# Episode 425/1000, Total Reward: -12
# Episode 426/1000, Total Reward: -63
# Episode 427/1000, Total Reward: -25
# Episode 428/1000, Total Reward: -44
# Episode 429/1000, Total Reward: -10
# Episode 430/1000, Total Reward: -19
# Episode 431/1000, Total Reward: -29
# Episode 432/1000, Total Reward: -10
# Episode 433/1000, Total Reward: -18
# Episode 434/1000, Total Reward: -63
# Episode 435/1000, Total Reward: -121
# Episode 436/1000, Total Reward: -87
# Episode 437/1000, Total Reward: -29
# Episode 438/1000, Total Reward: -23
# Episode 439/1000, Total Reward: -45
# Episode 440/1000, Total Reward: -80
# Episode 441/1000, Total Reward: -29
# Episode 442/1000, Total Reward: -69
# Episode 443/1000, Total Reward: -18
# Episode 444/1000, Total Reward: -11
# Episode 445/1000, Total Reward: -30
# Episode 446/1000, Total Reward: -51
# Episode 447/1000, Total Reward: -13
# Episode 448/1000, Total Reward: -46
# Episode 449/1000, Total Reward: -10
# Episode 450/1000, Total Reward: -10
# Episode 451/1000, Total Reward: -61
# Episode 452/1000, Total Reward: -28
# Episode 453/1000, Total Reward: -33
# Episode 454/1000, Total Reward: -10
# Episode 455/1000, Total Reward: -15
# Episode 456/1000, Total Reward: -13
# Episode 457/1000, Total Reward: -10
# Episode 458/1000, Total Reward: -11
# Episode 459/1000, Total Reward: -11
# Episode 460/1000, Total Reward: -14
# Episode 461/1000, Total Reward: -82
# Episode 462/1000, Total Reward: -20
# Episode 463/1000, Total Reward: -35
# Episode 464/1000, Total Reward: -50
# Episode 465/1000, Total Reward: -15
# Episode 466/1000, Total Reward: -16
# Episode 467/1000, Total Reward: -15
# Episode 468/1000, Total Reward: -17
# Episode 469/1000, Total Reward: -14
# Episode 470/1000, Total Reward: -12
# Episode 471/1000, Total Reward: -35
# Episode 472/1000, Total Reward: -10
# Episode 473/1000, Total Reward: -169
# Episode 474/1000, Total Reward: -58
# Episode 475/1000, Total Reward: -12
# Episode 476/1000, Total Reward: -55
# Episode 477/1000, Total Reward: -14
# Episode 478/1000, Total Reward: -66
# Episode 479/1000, Total Reward: -59
# Episode 480/1000, Total Reward: -12
# Episode 481/1000, Total Reward: -46
# Episode 482/1000, Total Reward: -35
# Episode 483/1000, Total Reward: -23
# Episode 484/1000, Total Reward: -33
# Episode 485/1000, Total Reward: -14
# Episode 486/1000, Total Reward: -15
# Episode 487/1000, Total Reward: -15
# Episode 488/1000, Total Reward: -35
# Episode 489/1000, Total Reward: -42
# Episode 490/1000, Total Reward: -19
# Episode 491/1000, Total Reward: -10
# Episode 492/1000, Total Reward: -76
# Episode 493/1000, Total Reward: -19
# Episode 494/1000, Total Reward: -11
# Episode 495/1000, Total Reward: -58
# Episode 496/1000, Total Reward: -24
# Episode 497/1000, Total Reward: -58
# Episode 498/1000, Total Reward: -18
# Episode 499/1000, Total Reward: -21
# Episode 500/1000, Total Reward: -55
# Episode 501/1000, Total Reward: -13
# Episode 502/1000, Total Reward: -47
# Episode 503/1000, Total Reward: -31
# Episode 504/1000, Total Reward: -10
# Episode 505/1000, Total Reward: -20
# Episode 506/1000, Total Reward: -16
# Episode 507/1000, Total Reward: -11
# Episode 508/1000, Total Reward: -11
# Episode 509/1000, Total Reward: -55
# Episode 510/1000, Total Reward: -55
# Episode 511/1000, Total Reward: -22
# Episode 512/1000, Total Reward: -29
# Episode 513/1000, Total Reward: -48
# Episode 514/1000, Total Reward: -36
# Episode 515/1000, Total Reward: -31
# Episode 516/1000, Total Reward: -34
# Episode 517/1000, Total Reward: -13
# Episode 518/1000, Total Reward: -47
# Episode 519/1000, Total Reward: -14
# Episode 520/1000, Total Reward: -17
# Episode 521/1000, Total Reward: -16
# Episode 522/1000, Total Reward: -26
# Episode 523/1000, Total Reward: -10
# Episode 524/1000, Total Reward: -42
# Episode 525/1000, Total Reward: -10
# Episode 526/1000, Total Reward: -20
# Episode 527/1000, Total Reward: -22
# Episode 528/1000, Total Reward: -14
# Episode 529/1000, Total Reward: -10
# Episode 530/1000, Total Reward: -10
# Episode 531/1000, Total Reward: -22
# Episode 532/1000, Total Reward: -15
# Episode 533/1000, Total Reward: -19
# Episode 534/1000, Total Reward: -35
# Episode 535/1000, Total Reward: -51
# Episode 536/1000, Total Reward: -63
# Episode 537/1000, Total Reward: -126
# Episode 538/1000, Total Reward: -21
# Episode 539/1000, Total Reward: -32
# Episode 540/1000, Total Reward: -12
# Episode 541/1000, Total Reward: -40
# Episode 542/1000, Total Reward: -13
# Episode 543/1000, Total Reward: -73
# Episode 544/1000, Total Reward: -33
# Episode 545/1000, Total Reward: -25
# Episode 546/1000, Total Reward: -84
# Episode 547/1000, Total Reward: -78
# Episode 548/1000, Total Reward: -21
# Episode 549/1000, Total Reward: -11
# Episode 550/1000, Total Reward: -23
# Episode 551/1000, Total Reward: -52
# Episode 552/1000, Total Reward: -12
# Episode 553/1000, Total Reward: -11
# Episode 554/1000, Total Reward: -52
# Episode 555/1000, Total Reward: -83
# Episode 556/1000, Total Reward: -27
# Episode 557/1000, Total Reward: -31
# Episode 558/1000, Total Reward: -77
# Episode 559/1000, Total Reward: -15
# Episode 560/1000, Total Reward: -59
# Episode 561/1000, Total Reward: -35
# Episode 562/1000, Total Reward: -18
# Episode 563/1000, Total Reward: -11
# Episode 564/1000, Total Reward: -17
# Episode 565/1000, Total Reward: -47
# Episode 566/1000, Total Reward: -13
# Episode 567/1000, Total Reward: -10
# Episode 568/1000, Total Reward: -37
# Episode 569/1000, Total Reward: -16
# Episode 570/1000, Total Reward: -23
# Episode 571/1000, Total Reward: -24
# Episode 572/1000, Total Reward: -73
# Episode 573/1000, Total Reward: -61
# Episode 574/1000, Total Reward: -41
# Episode 575/1000, Total Reward: -140
# Episode 576/1000, Total Reward: -47
# Episode 577/1000, Total Reward: -15
# Episode 578/1000, Total Reward: -15
# Episode 579/1000, Total Reward: -43
# Episode 580/1000, Total Reward: -90
# Episode 581/1000, Total Reward: -30
# Episode 582/1000, Total Reward: -10
# Episode 583/1000, Total Reward: -41
# Episode 584/1000, Total Reward: -14
# Episode 585/1000, Total Reward: -29
# Episode 586/1000, Total Reward: -11
# Episode 587/1000, Total Reward: -168
# Episode 588/1000, Total Reward: -50
# Episode 589/1000, Total Reward: -15
# Episode 590/1000, Total Reward: -13
# Episode 591/1000, Total Reward: -12
# Episode 592/1000, Total Reward: -49
# Episode 593/1000, Total Reward: -64
# Episode 594/1000, Total Reward: -11
# Episode 595/1000, Total Reward: -26
# Episode 596/1000, Total Reward: -43
# Episode 597/1000, Total Reward: -22
# Episode 598/1000, Total Reward: -19
# Episode 599/1000, Total Reward: -10
# Episode 600/1000, Total Reward: -24
# Episode 601/1000, Total Reward: -13
# Episode 602/1000, Total Reward: -31
# Episode 603/1000, Total Reward: -28
# Episode 604/1000, Total Reward: -11
# Episode 605/1000, Total Reward: -36
# Episode 606/1000, Total Reward: -16
# Episode 607/1000, Total Reward: -13
# Episode 608/1000, Total Reward: -112
# Episode 609/1000, Total Reward: -43
# Episode 610/1000, Total Reward: -10
# Episode 611/1000, Total Reward: -72
# Episode 612/1000, Total Reward: -38
# Episode 613/1000, Total Reward: -10
# Episode 614/1000, Total Reward: -34
# Episode 615/1000, Total Reward: -18
# Episode 616/1000, Total Reward: -17
# Episode 617/1000, Total Reward: -11
# Episode 618/1000, Total Reward: -11
# Episode 619/1000, Total Reward: -21
# Episode 620/1000, Total Reward: -91
# Episode 621/1000, Total Reward: -17
# Episode 622/1000, Total Reward: -14
# Episode 623/1000, Total Reward: -43
# Episode 624/1000, Total Reward: -53
# Episode 625/1000, Total Reward: -23
# Episode 626/1000, Total Reward: -21
# Episode 627/1000, Total Reward: -38
# Episode 628/1000, Total Reward: -34
# Episode 629/1000, Total Reward: -50
# Episode 630/1000, Total Reward: -25
# Episode 631/1000, Total Reward: -153
# Episode 632/1000, Total Reward: -14
# Episode 633/1000, Total Reward: -13
# Episode 634/1000, Total Reward: -10
# Episode 635/1000, Total Reward: -11
# Episode 636/1000, Total Reward: -24
# Episode 637/1000, Total Reward: -11
# Episode 638/1000, Total Reward: -96
# Episode 639/1000, Total Reward: -16
# Episode 640/1000, Total Reward: -49
# Episode 641/1000, Total Reward: -36
# Episode 642/1000, Total Reward: -16
# Episode 643/1000, Total Reward: -59
# Episode 644/1000, Total Reward: -21
# Episode 645/1000, Total Reward: -53
# Episode 646/1000, Total Reward: -10
# Episode 647/1000, Total Reward: -11
# Episode 648/1000, Total Reward: -39
# Episode 649/1000, Total Reward: -15
# Episode 650/1000, Total Reward: -10
# Episode 651/1000, Total Reward: -10
# Episode 652/1000, Total Reward: -62
# Episode 653/1000, Total Reward: -11
# Episode 654/1000, Total Reward: -16
# Episode 655/1000, Total Reward: -10
# Episode 656/1000, Total Reward: -13
# Episode 657/1000, Total Reward: -29
# Episode 658/1000, Total Reward: -20
# Episode 659/1000, Total Reward: -67
# Episode 660/1000, Total Reward: -16
# Episode 661/1000, Total Reward: -10
# Episode 662/1000, Total Reward: -16
# Episode 663/1000, Total Reward: -59
# Episode 664/1000, Total Reward: -28
# Episode 665/1000, Total Reward: -38
# Episode 666/1000, Total Reward: -24
# Episode 667/1000, Total Reward: -44
# Episode 668/1000, Total Reward: -63
# Episode 669/1000, Total Reward: -14
# Episode 670/1000, Total Reward: -16
# Episode 671/1000, Total Reward: -24
# Episode 672/1000, Total Reward: -31
# Episode 673/1000, Total Reward: -28
# Episode 674/1000, Total Reward: -16
# Episode 675/1000, Total Reward: -106
# Episode 676/1000, Total Reward: -40
# Episode 677/1000, Total Reward: -21
# Episode 678/1000, Total Reward: -19
# Episode 679/1000, Total Reward: -19
# Episode 680/1000, Total Reward: -16
# Episode 681/1000, Total Reward: -13
# Episode 682/1000, Total Reward: -12
# Episode 683/1000, Total Reward: -18
# Episode 684/1000, Total Reward: -15
# Episode 685/1000, Total Reward: -18
# Episode 686/1000, Total Reward: -15
# Episode 687/1000, Total Reward: -43
# Episode 688/1000, Total Reward: -28
# Episode 689/1000, Total Reward: -17
# Episode 690/1000, Total Reward: -15
# Episode 691/1000, Total Reward: -21
# Episode 692/1000, Total Reward: -40
# Episode 693/1000, Total Reward: -26
# Episode 694/1000, Total Reward: -24
# Episode 695/1000, Total Reward: -17
# Episode 696/1000, Total Reward: -98
# Episode 697/1000, Total Reward: -55
# Episode 698/1000, Total Reward: -48
# Episode 699/1000, Total Reward: -66
# Episode 700/1000, Total Reward: -11
# Episode 701/1000, Total Reward: -17
# Episode 702/1000, Total Reward: -130
# Episode 703/1000, Total Reward: -13
# Episode 704/1000, Total Reward: -57
# Episode 705/1000, Total Reward: -17
# Episode 706/1000, Total Reward: -16
# Episode 707/1000, Total Reward: -40
# Episode 708/1000, Total Reward: -14
# Episode 709/1000, Total Reward: -54
# Episode 710/1000, Total Reward: -13
# Episode 711/1000, Total Reward: -11
# Episode 712/1000, Total Reward: -10
# Episode 713/1000, Total Reward: -23
# Episode 714/1000, Total Reward: -54
# Episode 715/1000, Total Reward: -23
# Episode 716/1000, Total Reward: -10
# Episode 717/1000, Total Reward: -10
# Episode 718/1000, Total Reward: -91
# Episode 719/1000, Total Reward: -12
# Episode 720/1000, Total Reward: -10
# Episode 721/1000, Total Reward: -66
# Episode 722/1000, Total Reward: -10
# Episode 723/1000, Total Reward: -12
# Episode 724/1000, Total Reward: -97
# Episode 725/1000, Total Reward: -12
# Episode 726/1000, Total Reward: -55
# Episode 727/1000, Total Reward: -10
# Episode 728/1000, Total Reward: -10
# Episode 729/1000, Total Reward: -43
# Episode 730/1000, Total Reward: -46
# Episode 731/1000, Total Reward: -40
# Episode 732/1000, Total Reward: -12
# Episode 733/1000, Total Reward: -18
# Episode 734/1000, Total Reward: -24
# Episode 735/1000, Total Reward: -23
# Episode 736/1000, Total Reward: -47
# Episode 737/1000, Total Reward: -13
# Episode 738/1000, Total Reward: -10
# Episode 739/1000, Total Reward: -12
# Episode 740/1000, Total Reward: -15
# Episode 741/1000, Total Reward: -20
# Episode 742/1000, Total Reward: -42
# Episode 743/1000, Total Reward: -12
# Episode 744/1000, Total Reward: -23
# Episode 745/1000, Total Reward: -64
# Episode 746/1000, Total Reward: -28
# Episode 747/1000, Total Reward: -24
# Episode 748/1000, Total Reward: -15
# Episode 749/1000, Total Reward: -20
# Episode 750/1000, Total Reward: -49
# Episode 751/1000, Total Reward: -10
# Episode 752/1000, Total Reward: -61
# Episode 753/1000, Total Reward: -24
# Episode 754/1000, Total Reward: -30
# Episode 755/1000, Total Reward: -15
# Episode 756/1000, Total Reward: -15
# Episode 757/1000, Total Reward: -46
# Episode 758/1000, Total Reward: -50
# Episode 759/1000, Total Reward: -30
# Episode 760/1000, Total Reward: -23
# Episode 761/1000, Total Reward: -15
# Episode 762/1000, Total Reward: -35
# Episode 763/1000, Total Reward: -33
# Episode 764/1000, Total Reward: -10
# Episode 765/1000, Total Reward: -19
# Episode 766/1000, Total Reward: -73
# Episode 767/1000, Total Reward: -57
# Episode 768/1000, Total Reward: -12
# Episode 769/1000, Total Reward: -18
# Episode 770/1000, Total Reward: -11
# Episode 771/1000, Total Reward: -45
# Episode 772/1000, Total Reward: -29
# Episode 773/1000, Total Reward: -12
# Episode 774/1000, Total Reward: -12
# Episode 775/1000, Total Reward: -18
# Episode 776/1000, Total Reward: -35
# Episode 777/1000, Total Reward: -25
# Episode 778/1000, Total Reward: -14
# Episode 779/1000, Total Reward: -58
# Episode 780/1000, Total Reward: -19
# Episode 781/1000, Total Reward: -31
# Episode 782/1000, Total Reward: -13
# Episode 783/1000, Total Reward: -19
# Episode 784/1000, Total Reward: -10
# Episode 785/1000, Total Reward: -113
# Episode 786/1000, Total Reward: -16
# Episode 787/1000, Total Reward: -45
# Episode 788/1000, Total Reward: -12
# Episode 789/1000, Total Reward: -40
# Episode 790/1000, Total Reward: -17
# Episode 791/1000, Total Reward: -11
# Episode 792/1000, Total Reward: -31
# Episode 793/1000, Total Reward: -23
# Episode 794/1000, Total Reward: -10
# Episode 795/1000, Total Reward: -23
# Episode 796/1000, Total Reward: -15
# Episode 797/1000, Total Reward: -104
# Episode 798/1000, Total Reward: -90
# Episode 799/1000, Total Reward: -11
# Episode 800/1000, Total Reward: -23
# Episode 801/1000, Total Reward: -50
# Episode 802/1000, Total Reward: -15
# Episode 803/1000, Total Reward: -36
# Episode 804/1000, Total Reward: -85
# Episode 805/1000, Total Reward: -55
# Episode 806/1000, Total Reward: -17
# Episode 807/1000, Total Reward: -61
# Episode 808/1000, Total Reward: -135
# Episode 809/1000, Total Reward: -77
# Episode 810/1000, Total Reward: -40
# Episode 811/1000, Total Reward: -18
# Episode 812/1000, Total Reward: -12
# Episode 813/1000, Total Reward: -29
# Episode 814/1000, Total Reward: -14
# Episode 815/1000, Total Reward: -34
# Episode 816/1000, Total Reward: -15
# Episode 817/1000, Total Reward: -87
# Episode 818/1000, Total Reward: -17
# Episode 819/1000, Total Reward: -45
# Episode 820/1000, Total Reward: -14
# Episode 821/1000, Total Reward: -28
# Episode 822/1000, Total Reward: -56
# Episode 823/1000, Total Reward: -69
# Episode 824/1000, Total Reward: -15
# Episode 825/1000, Total Reward: -10
# Episode 826/1000, Total Reward: -15
# Episode 827/1000, Total Reward: -16
# Episode 828/1000, Total Reward: -13
# Episode 829/1000, Total Reward: -40
# Episode 830/1000, Total Reward: -207
# Episode 831/1000, Total Reward: -14
# Episode 832/1000, Total Reward: -16
# Episode 833/1000, Total Reward: -50
# Episode 834/1000, Total Reward: -102
# Episode 835/1000, Total Reward: -94
# Episode 836/1000, Total Reward: -28
# Episode 837/1000, Total Reward: -29
# Episode 838/1000, Total Reward: -73
# Episode 839/1000, Total Reward: -61
# Episode 840/1000, Total Reward: -14
# Episode 841/1000, Total Reward: -11
# Episode 842/1000, Total Reward: -19
# Episode 843/1000, Total Reward: -20
# Episode 844/1000, Total Reward: -11
# Episode 845/1000, Total Reward: -39
# Episode 846/1000, Total Reward: -17
# Episode 847/1000, Total Reward: -12
# Episode 848/1000, Total Reward: -36
# Episode 849/1000, Total Reward: -29
# Episode 850/1000, Total Reward: -10
# Episode 851/1000, Total Reward: -29
# Episode 852/1000, Total Reward: -52
# Episode 853/1000, Total Reward: -66
# Episode 854/1000, Total Reward: -52
# Episode 855/1000, Total Reward: -10
# Episode 856/1000, Total Reward: -29
# Episode 857/1000, Total Reward: -26
# Episode 858/1000, Total Reward: -26
# Episode 859/1000, Total Reward: -13
# Episode 860/1000, Total Reward: -21
# Episode 861/1000, Total Reward: -55
# Episode 862/1000, Total Reward: -48
# Episode 863/1000, Total Reward: -47
# Episode 864/1000, Total Reward: -56
# Episode 865/1000, Total Reward: -12
# Episode 866/1000, Total Reward: -21
# Episode 867/1000, Total Reward: -11
# Episode 868/1000, Total Reward: -46
# Episode 869/1000, Total Reward: -52
# Episode 870/1000, Total Reward: -71
# Episode 871/1000, Total Reward: -22
# Episode 872/1000, Total Reward: -30
# Episode 873/1000, Total Reward: -51
# Episode 874/1000, Total Reward: -25
# Episode 875/1000, Total Reward: -44
# Episode 876/1000, Total Reward: -24
# Episode 877/1000, Total Reward: -10
# Episode 878/1000, Total Reward: -22
# Episode 879/1000, Total Reward: -10
# Episode 880/1000, Total Reward: -26
# Episode 881/1000, Total Reward: -13
# Episode 882/1000, Total Reward: -68
# Episode 883/1000, Total Reward: -30
# Episode 884/1000, Total Reward: -27
# Episode 885/1000, Total Reward: -16
# Episode 886/1000, Total Reward: -13
# Episode 887/1000, Total Reward: -16
# Episode 888/1000, Total Reward: -45
# Episode 889/1000, Total Reward: -23
# Episode 890/1000, Total Reward: -16
# Episode 891/1000, Total Reward: -20
# Episode 892/1000, Total Reward: -10
# Episode 893/1000, Total Reward: -38
# Episode 894/1000, Total Reward: -120
# Episode 895/1000, Total Reward: -10
# Episode 896/1000, Total Reward: -10
# Episode 897/1000, Total Reward: -16
# Episode 898/1000, Total Reward: -12
# Episode 899/1000, Total Reward: -28
# Episode 900/1000, Total Reward: -10
# Episode 901/1000, Total Reward: -22
# Episode 902/1000, Total Reward: -10
# Episode 903/1000, Total Reward: -49
# Episode 904/1000, Total Reward: -31
# Episode 905/1000, Total Reward: -20
# Episode 906/1000, Total Reward: -54
# Episode 907/1000, Total Reward: -12
# Episode 908/1000, Total Reward: -14
# Episode 909/1000, Total Reward: -24
# Episode 910/1000, Total Reward: -16
# Episode 911/1000, Total Reward: -24
# Episode 912/1000, Total Reward: -22
# Episode 913/1000, Total Reward: -18
# Episode 914/1000, Total Reward: -34
# Episode 915/1000, Total Reward: -25
# Episode 916/1000, Total Reward: -58
# Episode 917/1000, Total Reward: -10
# Episode 918/1000, Total Reward: -10
# Episode 919/1000, Total Reward: -55
# Episode 920/1000, Total Reward: -27
# Episode 921/1000, Total Reward: -10
# Episode 922/1000, Total Reward: -36
# Episode 923/1000, Total Reward: -52
# Episode 924/1000, Total Reward: -40
# Episode 925/1000, Total Reward: -17
# Episode 926/1000, Total Reward: -12
# Episode 927/1000, Total Reward: -57
# Episode 928/1000, Total Reward: -64
# Episode 929/1000, Total Reward: -10
# Episode 930/1000, Total Reward: -16
# Episode 931/1000, Total Reward: -215
# Episode 932/1000, Total Reward: -21
# Episode 933/1000, Total Reward: -45
# Episode 934/1000, Total Reward: -93
# Episode 935/1000, Total Reward: -35
# Episode 936/1000, Total Reward: -10
# Episode 937/1000, Total Reward: -36
# Episode 938/1000, Total Reward: -15
# Episode 939/1000, Total Reward: -24
# Episode 940/1000, Total Reward: -16
# Episode 941/1000, Total Reward: -21
# Episode 942/1000, Total Reward: -11
# Episode 943/1000, Total Reward: -25
# Episode 944/1000, Total Reward: -15
# Episode 945/1000, Total Reward: -26
# Episode 946/1000, Total Reward: -43
# Episode 947/1000, Total Reward: -12
# Episode 948/1000, Total Reward: -52
# Episode 949/1000, Total Reward: -13
# Episode 950/1000, Total Reward: -11
# Episode 951/1000, Total Reward: -17
# Episode 952/1000, Total Reward: -19
# Episode 953/1000, Total Reward: -45
# Episode 954/1000, Total Reward: -15
# Episode 955/1000, Total Reward: -121
# Episode 956/1000, Total Reward: -13
# Episode 957/1000, Total Reward: -27
# Episode 958/1000, Total Reward: -15
# Episode 959/1000, Total Reward: -10
# Episode 960/1000, Total Reward: -15
# Episode 961/1000, Total Reward: -23
# Episode 962/1000, Total Reward: -49
# Episode 963/1000, Total Reward: -23
# Episode 964/1000, Total Reward: -26
# Episode 965/1000, Total Reward: -71
# Episode 966/1000, Total Reward: -19
# Episode 967/1000, Total Reward: -20
# Episode 968/1000, Total Reward: -10
# Episode 969/1000, Total Reward: -28
# Episode 970/1000, Total Reward: -27
# Episode 971/1000, Total Reward: -28
# Episode 972/1000, Total Reward: -22
# Episode 973/1000, Total Reward: -56
# Episode 974/1000, Total Reward: -32
# Episode 975/1000, Total Reward: -19
# Episode 976/1000, Total Reward: -22
# Episode 977/1000, Total Reward: -20
# Episode 978/1000, Total Reward: -16
# Episode 979/1000, Total Reward: -13
# Episode 980/1000, Total Reward: -18
# Episode 981/1000, Total Reward: -44
# Episode 982/1000, Total Reward: -17
# Episode 983/1000, Total Reward: -60
# Episode 984/1000, Total Reward: -20
# Episode 985/1000, Total Reward: -35
# Episode 986/1000, Total Reward: -10
# Episode 987/1000, Total Reward: -38
# Episode 988/1000, Total Reward: -20
# Episode 989/1000, Total Reward: -12
# Episode 990/1000, Total Reward: -10
# Episode 991/1000, Total Reward: -17
# Episode 992/1000, Total Reward: -41
# Episode 993/1000, Total Reward: -26
# Episode 994/1000, Total Reward: -13
# Episode 995/1000, Total Reward: -26
# Episode 996/1000, Total Reward: -39
# Episode 997/1000, Total Reward: -34
# Episode 998/1000, Total Reward: -121
# Episode 999/1000, Total Reward: -133
# Episode 1000/1000, Total Reward: -11
# Average reward over 10 test episodes: -30.5

# %% [markdown]
# Overall, it is implementing a DQN agent that learns to make decisions in an environment through interaction and reinforcement learning:
#
# 1. **DQN Class**: Represents the neural network architecture for the Deep Q-Network (DQN) used by the agent.
#
# 2. **DQNAgent Class**: Represents the agent that interacts with the environment, learns from experiences, and makes decisions.
#    - **Initialization**: Sets up the agent with the given state and action sizes, creates neural networks, and initializes exploration parameters.
#    - **act**: Chooses actions based on an epsilon-greedy policy.
#    - **remember**: Stores experiences (state, action, reward, next state, done) in a replay buffer.
#    - **replay**: Samples experiences from the replay buffer and updates the model.
#    - **update_target_model**: Updates the target network's weights to match the main network's weights.
#    - **train**: Trains the agent by interacting with the environment and updating the model.
#
# 3. **Training and Testing**:
#    - Initializes the environment, state size, action size, and the agent.
#    - Trains the agent for a specified number of episodes.
#    - Tests the trained agent by running it for a certain number of test episodes and evaluating its performance based on the total rewards obtained.
